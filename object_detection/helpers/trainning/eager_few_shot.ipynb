# %%
import os
import pathlib

# %%
import matplotlib
import matplotlib.pyplot as plt

import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder

# %matplotlib inline

# %% [markdown]
# # Utilities

# %%
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.

  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.

  Args:
    path: a file path.

  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

def plot_detections(image_np,
                    boxes,
                    classes,
                    scores,
                    category_index,
                    figsize=(12, 16),
                    image_name=None):
  """Wrapper function to visualize detections.

  Args:
    image_np: uint8 numpy array with shape (img_height, img_width, 3)
    boxes: a numpy array of shape [N, 4]
    classes: a numpy array of shape [N]. Note that class indices are 1-based,
      and match the keys in the label map.
    scores: a numpy array of shape [N] or None.  If scores=None, then
      this function assumes that the boxes to be plotted are groundtruth
      boxes and plot all boxes as black with no classes or scores.
    category_index: a dict containing category dictionaries (each holding
      category index `id` and category name `name`) keyed by category indices.
    figsize: size for the figure.
    image_name: a name for the image file.
  """
  image_np_with_annotations = image_np.copy()
  viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_annotations,
      boxes,
      classes,
      scores,
      category_index,
      use_normalized_coordinates=True,
      min_score_thresh=0.8)
  if image_name:
    plt.imsave(image_name, image_np_with_annotations)
  else:
    plt.imshow(image_np_with_annotations)

# %%
# Load images and visualize
import glob
train_image_dir = '/Users/grubio/Downloads/bounding_boxes/blackprincess/'
train_images_np = []
for i in glob.glob(f"train_image_dir/*.jpg"):
  # image_path = os.path.join(train_image_dir, 'robertducky' + str(i) + '.jpg')
  train_images_np.append(load_image_into_numpy_array(i))

train_images_np.append(load_image_into_numpy_array(f"{train_image_dir}/blackprincess_0_1610418331.57383.jpg"))
# train_images_np.append(load_image_into_numpy_array(f"{train_image_dir}/blackprincess_0_1610418549.765324.jpg"))
# train_images_np.append(load_image_into_numpy_array(f"{train_image_dir}/blackprincess_0_1610418748.123847.jpg"))
# train_images_np.append(load_image_into_numpy_array(f"{train_image_dir}/blackprincess_0_1610418880.130402.jpg"))
# train_images_np.append(load_image_into_numpy_array(f"{train_image_dir}/blackprincess_0_1610418696.784677.jpg"))
# train_images_np.append(load_image_into_numpy_array(f"{train_image_dir}/blackprincess_0_1610420448.133373.jpg"))


plt.rcParams['axes.grid'] = False
plt.rcParams['xtick.labelsize'] = False
plt.rcParams['ytick.labelsize'] = False
plt.rcParams['xtick.top'] = False
plt.rcParams['xtick.bottom'] = False
plt.rcParams['ytick.left'] = False
plt.rcParams['ytick.right'] = False
plt.rcParams['figure.figsize'] = [14, 7]

for idx, train_image_np in enumerate(train_images_np):
  plt.subplot(2, 3, idx+1)
  plt.imshow(train_image_np)
plt.show()

# %% [markdown]
# # In case you didn't want to label...
#
# Run this cell only if you didn't annotate anything above and
# would prefer to just use our preannotated boxes.  Don't forget
# to uncomment.

# %%
gt_boxes = [
            np.array([[0, 0, 300, 800]], dtype=np.float32),
            np.array([[0, 0, 300, 300]], dtype=np.float32),
            np.array([[0, 0, 300, 300]], dtype=np.float32),
            np.array([[0, 0, 300, 300]], dtype=np.float32),
            np.array([[0, 0, 300, 300]], dtype=np.float32),
            np.array([[0, 0, 300, 800]], dtype=np.float32),


]

# %% [markdown]
# # Prepare data for training
#
# Below we add the class annotations (for simplicity, we assume a single class in this colab; though it should be straightforward to extend this to handle multiple classes).  We also convert everything to the format that the training
# loop below expects (e.g., everything converted to tensors, classes converted to one-hot representations, etc.).

# %%
# By convention, our non-background classes start counting at 1.  Given
# that we will be predicting just one class, we will therefore assign it a
# `class id` of 1.
duck_class_id = 1
num_classes = 1

category_index = {duck_class_id: {'id': duck_class_id, 'name': 'blackprincess'}}

# Convert class labels to one-hot; convert everything to tensors.
# The `label_id_offset` here shifts all classes by a certain number of indices;
# we do this here so that the model receives one-hot labels where non-background
# classes start counting at the zeroth index.  This is ordinarily just handled
# automatically in our training binaries, but we need to reproduce it here.
label_id_offset = 1
train_image_tensors = []
gt_classes_one_hot_tensors = []
gt_box_tensors = []
for (train_image_np, gt_box_np) in zip(
    train_images_np, gt_boxes):
  train_image_tensors.append(tf.expand_dims(tf.convert_to_tensor(
      train_image_np, dtype=tf.float32), axis=0))
  gt_box_tensors.append(tf.convert_to_tensor(gt_box_np, dtype=tf.float32))
  zero_indexed_groundtruth_classes = tf.convert_to_tensor(
      np.ones(shape=[gt_box_np.shape[0]], dtype=np.int32) - label_id_offset)
  gt_classes_one_hot_tensors.append(tf.one_hot(
      zero_indexed_groundtruth_classes, num_classes))
print('Done prepping data.')
# Out:
# Done prepping data.

# %% [markdown]
# # Let's just visualize the rubber duckies as a sanity check

# %%
dummy_scores = np.array([1.0], dtype=np.float32)  # give boxes a score of 100%

plt.figure(figsize=(30, 15))
for idx in range(6):
  plt.subplot(2, 3, idx+1)
  plot_detections(
      train_images_np[idx],
      gt_boxes[idx],
      np.ones(shape=[gt_boxes[idx].shape[0]], dtype=np.int32),
      dummy_scores, category_index)
plt.show()

# %% [markdown]
# # Create model and restore weights for all but last layer
#
# In this cell we build a single stage detection architecture (RetinaNet) and restore all but the classification layer at the top (which will be automatically randomly initialized).
#
# For simplicity, we have hardcoded a number of things in this colab for the specific RetinaNet architecture at hand (including assuming that the image size will always be 640x640), however it is not difficult to generalize to other model configurations.

# %%
# Download the checkpoint and put it into models/research/object_detection/test_data/

# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !tar -xf ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# !mv ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/checkpoint models/research/object_detection/test_data/
# Out:
# --2021-01-17 18:33:04--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 2800:3f0:4001:81b::2010, 172.217.173.112
# Connecting to download.tensorflow.org (download.tensorflow.org)|2800:3f0:4001:81b::2010|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244817203 (233M) [application/x-tar]
# Saving to: ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet50_v1_fpn 100%[===================>] 233,48M  3,55MB/s    in 84s
#
# 2021-01-17 18:34:28 (2,79 MB/s) - ‘ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [244817203/244817203]

# %%
tf.keras.backend.clear_session()

print('Building model and restoring weights for fine-tuning...', flush=True)
num_classes = 1
pipeline_config = 'models/research/object_detection/configs/tf2/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8.config'
checkpoint_path = 'models/research/object_detection/test_data/checkpoint/ckpt-0'

# Load pipeline config and build a detection model.
#
# Since we are working off of a COCO architecture which predicts 90
# class slots by default, we override the `num_classes` field here to be just
# one (for our new rubber ducky class).
configs = config_util.get_configs_from_pipeline_file(pipeline_config)
model_config = configs['model']
model_config.ssd.num_classes = num_classes
model_config.ssd.freeze_batchnorm = True
detection_model = model_builder.build(
      model_config=model_config, is_training=True)

# Set up object-based checkpoint restore --- RetinaNet has two prediction
# `heads` --- one for classification, the other for box regression.  We will
# restore the box regression head but initialize the classification head
# from scratch (we show the omission below by commenting out the line that
# we would add if we wanted to restore both heads)
fake_box_predictor = tf.compat.v2.train.Checkpoint(
    _base_tower_layers_for_heads=detection_model._box_predictor._base_tower_layers_for_heads,
    # _prediction_heads=detection_model._box_predictor._prediction_heads,
    #    (i.e., the classification head that we *will not* restore)
    _box_prediction_head=detection_model._box_predictor._box_prediction_head,
    )
fake_model = tf.compat.v2.train.Checkpoint(
          _feature_extractor=detection_model._feature_extractor,
          _box_predictor=fake_box_predictor)
ckpt = tf.compat.v2.train.Checkpoint(model=fake_model)
ckpt.restore(checkpoint_path).expect_partial()

# Run model through a dummy image so that variables are created
image, shapes = detection_model.preprocess(tf.zeros([1, 640, 640, 3]))
prediction_dict = detection_model.predict(image, shapes)
_ = detection_model.postprocess(prediction_dict, shapes)
print('Weights restored!')
# Out:
# Building model and restoring weights for fine-tuning...
# Weights restored!

# %% [markdown]
# # Eager mode custom training loop

# %%
tf.keras.backend.set_learning_phase(True)

# These parameters can be tuned; since our training set has 5 images
# it doesn't make sense to have a much larger batch size, though we could
# fit more examples in memory if we wanted to.
batch_size = 4
learning_rate = 0.01
num_batches = 500

# Select variables in top layers to fine-tune.
trainable_variables = detection_model.trainable_variables
to_fine_tune = []
prefixes_to_train = [
  'WeightSharedConvolutionalBoxPredictor/WeightSharedConvolutionalBoxHead',
  'WeightSharedConvolutionalBoxPredictor/WeightSharedConvolutionalClassHead']
for var in trainable_variables:
  if any([var.name.startswith(prefix) for prefix in prefixes_to_train]):
    to_fine_tune.append(var)

# Set up forward + backward pass for a single train step.
def get_model_train_step_function(model, optimizer, vars_to_fine_tune):
  """Get a tf.function for training step."""

  # Use tf.function for a bit of speed.
  # Comment out the tf.function decorator if you want the inside of the
  # function to run eagerly.
  @tf.function
  def train_step_fn(image_tensors,
                    groundtruth_boxes_list,
                    groundtruth_classes_list):
    """A single training iteration.

    Args:
      image_tensors: A list of [1, height, width, 3] Tensor of type tf.float32.
        Note that the height and width can vary across images, as they are
        reshaped within this function to be 640x640.
      groundtruth_boxes_list: A list of Tensors of shape [N_i, 4] with type
        tf.float32 representing groundtruth boxes for each image in the batch.
      groundtruth_classes_list: A list of Tensors of shape [N_i, num_classes]
        with type tf.float32 representing groundtruth boxes for each image in
        the batch.

    Returns:
      A scalar tensor representing the total loss for the input batch.
    """
    shapes = tf.constant(batch_size * [[640, 640, 3]], dtype=tf.int32)
    model.provide_groundtruth(
        groundtruth_boxes_list=groundtruth_boxes_list,
        groundtruth_classes_list=groundtruth_classes_list)
    with tf.GradientTape() as tape:
      preprocessed_images = tf.concat(
          [detection_model.preprocess(image_tensor)[0]
           for image_tensor in image_tensors], axis=0)
      prediction_dict = model.predict(preprocessed_images, shapes)
      losses_dict = model.loss(prediction_dict, shapes)
      total_loss = losses_dict['Loss/localization_loss'] + losses_dict['Loss/classification_loss']
      gradients = tape.gradient(total_loss, vars_to_fine_tune)
      optimizer.apply_gradients(zip(gradients, vars_to_fine_tune))
    return total_loss

  return train_step_fn

optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
train_step_fn = get_model_train_step_function(
    detection_model, optimizer, to_fine_tune)

print('Start fine-tuning!', flush=True)
for idx in range(num_batches):
  # Grab keys for a random subset of examples
  all_keys = list(range(len(train_images_np)))
  random.shuffle(all_keys)
  example_keys = all_keys[:batch_size]

  # Note that we do not do data augmentation in this demo.  If you want a
  # a fun exercise, we recommend experimenting with random horizontal flipping
  # and random cropping :)
  gt_boxes_list = [gt_box_tensors[key] for key in example_keys]
  gt_classes_list = [gt_classes_one_hot_tensors[key] for key in example_keys]
  image_tensors = [train_image_tensors[key] for key in example_keys]

  # Training step (forward pass + backwards pass)
  total_loss = train_step_fn(image_tensors, gt_boxes_list, gt_classes_list)

  if idx % 10 == 0:
    print('batch ' + str(idx) + ' of ' + str(num_batches)
    + ', loss=' +  str(total_loss.numpy()), flush=True)

print('Done fine-tuning!')
# Out:
# Start fine-tuning!
# batch 0 of 100, loss=911.7897
# WARNING:tensorflow:5 out of the last 7 calls to <function get_model_train_step_function.<locals>.train_step_fn at 0x7f859b1c88b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function get_model_train_step_function.<locals>.train_step_fn at 0x7f859b1c88b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# batch 10 of 100, loss=801.9091
# batch 20 of 100, loss=844.4663
# batch 30 of 100, loss=782.06775
# batch 40 of 100, loss=641.90173
# batch 50 of 100, loss=579.42474
# batch 60 of 100, loss=637.074
# batch 70 of 100, loss=476.457
# batch 80 of 100, loss=522.0435
# batch 90 of 100, loss=366.7396
# Done fine-tuning!

# %% [markdown]
# # Load test images and run inference with new model!

# %%
test_image_dir = '/Users/grubio/Downloads/bounding_boxes/blackprincess/'
test_images_np = []
count=0
for i in glob.glob("/Users/grubio/Downloads/bounding_boxes/blackprincess/*jpg"):
  count+=1
  if count==30:
    break
  # print(i)
  image_path = i
  test_images_np.append(np.expand_dims(
      load_image_into_numpy_array(image_path), axis=0))

# Again, uncomment this decorator if you want to run inference eagerly
@tf.function
def detect(input_tensor):
  """Run detection on an input image.

  Args:
    input_tensor: A [1, height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.

  Returns:
    A dict containing 3 Tensors (`detection_boxes`, `detection_classes`,
      and `detection_scores`).
  """
  preprocessed_image, shapes = detection_model.preprocess(input_tensor)
  prediction_dict = detection_model.predict(preprocessed_image, shapes)
  return detection_model.postprocess(prediction_dict, shapes)

# Note that the first frame will trigger tracing of the tf.function, which will
# take some time, after which inference should be fast.

label_id_offset = 1
for i in range(len(test_images_np)):
  input_tensor = tf.convert_to_tensor(test_images_np[i], dtype=tf.float32)
  detections = detect(input_tensor)

  plot_detections(
      test_images_np[i][0],
      detections['detection_boxes'][0].numpy(),
      detections['detection_classes'][0].numpy().astype(np.uint32)
      + label_id_offset,
      detections['detection_scores'][0].numpy(),
      category_index, figsize=(15, 20), image_name="gif_frame_" + ('%02d' % i) + ".jpg")
# Out:
# wnloads/bounding_boxes/blackprincess/blackprincess_103_1610420458.520873.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_88_1610420548.395068.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_263_1610420474.543988.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_81_1610418885.966293.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_87_1610420456.911935.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_27_1610420638.8845599.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_195_1610418762.21695.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_235_1610420471.733556.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_564_1610420504.708438.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_430_1610420491.260119.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_302_1610418769.72454.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_21_1610418881.760709.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_101_1610418338.716334.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_434_1610420491.655678.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_604_1610420508.716681.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_155_1610418759.2768881.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_59_1610418884.3990989.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_341_1610420482.347309.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_615_1610420509.8133702.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_115_1610420647.758226.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_19_1610420585.613643.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_88_1610420645.058453.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_94_1610420645.661462.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_130_1610418340.8068988.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_98_1610420646.0571818.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_67_1610420642.9573262.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_0_1610420430.9758332.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_313_1610418770.484803.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_250_1610418349.113747.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_123_1610418705.655599.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_66_1610420437.644795.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_6_1610420448.806912.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_144_1610418707.098141.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_101_1610420646.3593311.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_551_1610420503.3993049.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_10_1610420584.711532.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_274_1610420475.6451929.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_3_1610420567.712459.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_270_1610420475.244576.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_794_1610418387.487764.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_265_1610418350.147727.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_234_1610418566.41217.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_56_1610420545.1906729.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_74_1610420643.657899.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_464_1610420494.659786.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_50_1610420436.0438368.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_79_1610420591.625195.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_127_1610418889.20281.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_307_1610420478.9483259.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_91_1610420592.818969.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_706_1610418381.284599.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_144_1610418758.510819.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_195_1610420467.732277.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_663_1610418378.2132301.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_171_1610418892.3357608.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_190_1610418344.945627.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_66_1610418884.900214.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_60_1610420642.256066.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_518_1610420500.1039941.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_91_1610420645.360395.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_17_1610420432.747999.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_58_1610420436.843821.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_37_1610420639.888969.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_99_1610420458.1241002.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_48_1610420588.520639.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_13_1610420585.0122938.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_292_1610418570.5502899.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_456_1610418363.760906.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_91_1610418754.840339.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_24_1610420433.442486.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_530_1610420501.2990541.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_423_1610420490.5567691.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_0_1610418696.784677.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_481_1610420496.358589.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_87_1610418556.009102.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_246_1610418897.808457.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_254_1610418898.343681.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_242_1610420472.434051.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_559_1610418370.9722471.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_34_1610420639.58707.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_29_1610420542.4976032.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_575_1610420505.8113868.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_156_1610420463.829819.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_66_1610420546.1932101.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_526_1610420500.8986309.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_544_1610418369.931054.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_72_1610420455.415759.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_104_1610420646.6606321.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_32_1610420570.619854.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_373_1610420485.5489228.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_37_1610420587.420086.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_445_1610420492.752149.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_488_1610420497.058132.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_583_1610420506.6046531.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_14_1610420432.4387698.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_90_1610418703.41983.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_8_1610418748.866824.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_280_1610418351.187458.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_113_1610420459.524288.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_83_1610420456.51458.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_280_1610418768.186569.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_392_1610420487.450816.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_85_1610420644.757528.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_334_1610418771.953341.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_407_1610420488.951141.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_297_1610420477.941403.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_177_1610420465.93009.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_40_1610420587.720486.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_0_1610418331.57383.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_119_1610418888.63629.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_124_1610420460.626385.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_6_1610420540.19362.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_63_1610420642.5564291.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_70_1610420643.2585542.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_98_1610420593.527383.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_72_1610418336.671711.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_212_1610420469.4392169.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_69_1610420437.9468758.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_3_1610420448.500371.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_23_1610420586.008492.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_31_1610420451.3141901.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_108_1610420647.0619678.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_90_1610420457.214828.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_3_1610420539.883125.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_49_1610420544.500375.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_256_1610420473.838.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_175_1610418709.265701.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_140_1610420650.25774.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_219_1610418565.319534.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_220_1610418347.016497.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_522_1610420500.5028439.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_238_1610420472.038414.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_28_1610418333.632701.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_32_1610420434.240778.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_344_1610420482.652638.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_175_1610418343.8791292.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_6_1610420636.748638.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_126_1610420648.861612.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_40_1610420571.4176261.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_514_1610418367.863647.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_16_1610420541.196188.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_112_1610418888.10076.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_414_1610418360.565305.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_3_1610420636.4414349.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_426_1610420490.857974.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_46_1610420452.8176808.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_43_1610420435.341064.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_36_1610420543.1914911.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_46_1610420435.649573.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_292_1610418900.9824882.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_206_1610418762.979039.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_70_1610418753.338558.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_84_1610420547.996937.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_256_1610418715.071417.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_53_1610420453.51473.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_736_1610418383.346965.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_16_1610420637.7521229.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_19_1610420638.084689.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_174_1610418562.2471979.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_415_1610420489.748567.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_47_1610420572.123839.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_34_1610420587.1150029.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_348_1610420483.052468.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_205_1610420468.733135.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_116_1610418339.7747562.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_355_1610418773.39058.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_51_1610418883.863019.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_605_1610418374.106055.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_572_1610420505.504514.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_216_1610418763.718003.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_249_1610418766.0156102.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_80_1610418702.6607392.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_58_1610418335.671392.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_252_1610420473.438365.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_19_1610420541.497684.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_191_1610420467.334579.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_42_1610418552.866241.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_187_1610418893.414279.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_575_1610418372.032177.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_39_1610420434.945523.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_143_1610420650.566858.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_50_1610420641.2493079.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_388_1610420487.055889.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_136_1610420649.861839.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_179_1610418892.8732102.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_238_1610418765.252537.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_0_1610420636.075796.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_529_1610418368.868753.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_94_1610420549.0043032.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_32_1610420542.798336.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_73_1610420438.3517928.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_18_1610420569.218229.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_38_1610420452.014674.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_612_1610420509.507927.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_322_1610420480.447567.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_471_1610420495.3569012.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_366_1610420484.850066.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_249_1610418567.4553442.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_20_1610420450.212047.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_94_1610420593.12744.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_356_1610418356.391348.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_205_1610418564.312397.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_10_1610420449.203956.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_55_1610420572.9216352.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_319_1610420480.146237.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_46_1610420544.199554.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_385_1610418358.4580622.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_808_1610418388.489909.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_52_1610420544.802119.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_86_1610418337.674944.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_25_1610420569.917063.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_138_1610420462.028609.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_13_1610418332.605839.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_429_1610418361.590869.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_691_1610418380.246114.jpg
# /Users/grubio/Downloads/bounding_boxes/blackprincess/blackprincess_70_1610420546.603023.jpg

# %%
imageio.plugins.freeimage.download()

anim_file = 'duckies_test.gif'

filenames = glob.glob('gif_frame_*.jpg')
filenames = sorted(filenames)
last = -1
images = []
for filename in filenames:
  image = imageio.imread(filename)
  images.append(image)

imageio.mimsave(anim_file, images, 'GIF-FI', fps=5)

display(IPyImage(open(anim_file, 'rb').read()))
